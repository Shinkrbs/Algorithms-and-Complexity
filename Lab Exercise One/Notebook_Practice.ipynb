# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,100,1)
y = x**2
w = 2*x**2
plt.title("Running Time of Algorithm")
plt.xlabel("Size of Input")
plt.ylabel("Time")
plt.plot(x, w, 'b')
plt.plot(x, y, 'g')

# %% [markdown]
# # THIS IS A TITLE

# %% [markdown]
# This are some random gibberish just to say what is happening in the world!? By the way, Hello World!
